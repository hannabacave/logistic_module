# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from matplotlib import animation
import Logistic_and_vectorization as lv

# %%
# %matplotlib notebook
# Out:
# Traceback (most recent call last):
#   File "C:\Users\hbaca\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "C:\Users\hbaca\Anaconda3\lib\site-packages\matplotlib\animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
fig, ax = plt.subplots()

ax.plot([0, 1], [0, 1], 'black', lw=2)
line, = ax.plot([], [],color='r')
courbe, = ax.plot([], [], color='b')
x = np.linspace(0,1)

def init():
    line.set_data([], [])
    courbe.set_data([],[])
    return line,
    
def animate(i):
    line.set_data(zip(*lv.vectorization(0.05,0.05+i*0.05, 40)))
    courbe.set_data(x, lv.logistic(0.05+i*0.05,x))
    return line,

anim = animation.FuncAnimation(fig, animate, init_func=init,frames=82, interval=40)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def logistic(r, x):
    return r*x*(1-x)

# %%
n = 10000
r = np.linspace(2.5, 4.0, n)
iterations = 1000
last = 100
y = 1e-5 * np.ones(n)

# %%
fig, ax = plt.subplots()

for i in range(iterations):
    y = logistic(r, y)
    if i >= (iterations - last):
        ax.plot(r, x, alpha=.25)
ax.set_xlim(2.5, 4)
ax.set_title("Bifurcation diagram")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
